# %% [markdown]
# <a href="https://colab.research.google.com/github/joannevarughese/CIT-Capstone/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import csv
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/RestaurantRecommendationData/restaurants.csv') #importing dataset

# %%
df.describe()
# Out:
#                  id      position         score       ratings           lat  \
# count  63469.000000  63469.000000  35302.000000  35302.000000  63469.000000
# mean   31735.000000     86.692102      4.551431     74.887060     36.585019
# std    18322.066455     79.280129      0.300675     69.874057      6.458959
# min        1.000000      1.000000      1.300000     10.000000      0.000000
# 25%    15868.000000     18.000000      4.400000     25.000000     30.442221
# 50%    31735.000000     61.000000      4.600000     52.000000     34.707265
# 75%    47602.000000    141.000000      4.800000    100.000000     40.884903
# max    63469.000000    300.000000      5.000000    500.000000     48.963950
#
#                 lng
# count  63469.000000
# mean     -96.715114
# std       14.438166
# min     -123.841240
# 25%      -98.569760
# 50%      -96.764330
# 75%      -87.938729
# max        0.000000

# %%
df
# Out:
#           id  position                                            name  score  \
# 0          1        19               PJ Fresh (224 Daniel Payne Drive)    NaN
# 1          2         9                  J' ti`'z Smoothie-N-Coffee Bar    NaN
# 2          3         6  Philly Fresh Cheesesteaks (541-B Graymont Ave)    NaN
# 3          4        17         Papa Murphy's (1580 Montgomery Highway)    NaN
# 4          5       162                Nelson Brothers Cafe (17th St N)    4.7
# ...      ...       ...                                             ...    ...
# 63464  63465         2                           IHOP (4321 N 10th St)    4.6
# 63465  63466        29                       Feldman's - N 10th Street    NaN
# 63466  63467        27                           Feldman's - N 23rd St    NaN
# 63467  63468        19           Church's Chicken (620 S. 10th Street)    4.3
# 63468  63469         9                       7-Eleven (1600 S 23rd St)    NaN
#
#        ratings                                           category price_range  \
# 0          NaN                      Burgers, American, Sandwiches           $
# 1          NaN   Coffee and Tea, Breakfast and Brunch, Bubble Tea         NaN
# 2          NaN         American, Cheesesteak, Sandwiches, Alcohol           $
# 3          NaN                                              Pizza           $
# 4         22.0          Breakfast and Brunch, Burgers, Sandwiches         NaN
# ...        ...                                                ...         ...
# 63464     56.0  American, Breakfast and Brunch, burger, Comfor...           $
# 63465      NaN                                                NaN         NaN
# 63466      NaN                                                NaN         NaN
# 63467     17.0                            Fast Food, Family Meals           $
# 63468      NaN  Everyday Essentials, Convenience, Home &amp; P...           $
#
#                                             full_address zip_code        lat  \
# 0          224 Daniel Payne Drive, Birmingham, AL, 35207    35207  33.562365
# 1      1521 Pinson Valley Parkway, Birmingham, AL, 35217    35217  33.583640
# 2              541-B Graymont Ave, Birmingham, AL, 35204    35204  33.509800
# 3             1580 Montgomery Highway, Hoover, AL, 35226    35226  33.404439
# 4                   314 17th St N, Birmingham, AL, 35203    35203  33.514730
# ...                                                  ...      ...        ...
# 63464                4321 N 10th St, MC ALLEN, TX, 78504    78504  26.242853
# 63465                 3010 N 10th Street, Mc Allen, TX,       NaN  26.230764
# 63466              6101 N 23rd Street #B, Mc Allen, TX,       NaN  26.260353
# 63467             620 S. 10th Street, McAllen, TX, 78501    78501  26.197333
# 63468                 1600 S 23rd St, Mcallen, TX, 78503    78503  26.191710
#
#              lng
# 0     -86.830703
# 1     -86.773330
# 2     -86.854640
# 3     -86.806614
# 4     -86.811700
# ...          ...
# 63464 -98.223984
# 63465 -98.224922
# 63466 -98.236755
# 63467 -98.231369
# 63468 -98.247880
#
# [63469 rows x 11 columns]

# %%
ratings_df = df['ratings']
ratings_df.dropna(inplace=True) #gets rid of NaN values
ratings_df.head()
# Out:
# 4     22.0
# 6     63.0
# 13    44.0
# 15    20.0
# 18    48.0
# Name: ratings, dtype: float64

# %%
ratings_df.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 35302 entries, 4 to 63467
# Series name: ratings
# Non-Null Count  Dtype
# --------------  -----
# 35302 non-null  float64
# dtypes: float64(1)
# memory usage: 551.6 KB

# %%
sns.countplot(x=ratings_df)
# Out:
# <Axes: xlabel='ratings', ylabel='count'>

# %%
filter_list= ['23060', '23059', '23233', '23294']
filterDF = df.loc[df['zip_code'].isin(filter_list)]
filterDF = filterDF[df['category'].str.contains('Convenience')==False] #taking out any resturants that has that specific value like cafe in category
filterDF = filterDF[df['category'].str.contains('Desserts')==False]
filterDF = filterDF[df['category'].str.contains('Juice')==False]
filterDF = filterDF[df['category'].str.contains('Bakery')==False]
filterDF = filterDF[df['category'].str.contains('Cafe')==False]
#df.loc[df['zip_code']=='23060']
# Out:
# <ipython-input-10-8ed898c9e195>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filterDF = filterDF[df['category'].str.contains('Convenience')==False] #taking out any resturants that has that specific value like cafe in category
# <ipython-input-10-8ed898c9e195>:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filterDF = filterDF[df['category'].str.contains('Desserts')==False]
# <ipython-input-10-8ed898c9e195>:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filterDF = filterDF[df['category'].str.contains('Juice')==False]
# <ipython-input-10-8ed898c9e195>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filterDF = filterDF[df['category'].str.contains('Bakery')==False]
# <ipython-input-10-8ed898c9e195>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filterDF = filterDF[df['category'].str.contains('Cafe')==False]

# %%
filterDF
# Out:
#           id  position                                               name  \
# 23786  23787       126                                       Crab Du Jour
# 23791  23792       120                                       Kabab Bistro
# 23821  23822        56  Nuevo Mexico Restaurante (Richmond - Staples M...
# 23836  23837        12                              True Taste Restaurant
# 23867  23868       220                 Songwriters Cafe (9990 Brook Road)
# ...      ...       ...                                                ...
# 27650  27651        44                        Wendy's  (10177 Brook Road)
# 27655  27656        44  Chipotle Mexican Grill (1070 Virginia Center P...
# 27670  27671       132                           Subway (7250 W Broad St)
# 28466  28467        12                       McDonald's® (10000 BROOK RD)
# 28469  28470         5                 Popeyes (10213 Washington Highway)
#
#        score  ratings                                           category  \
# 23786    NaN      NaN                            Seafood, Chicken, Wings
# 23791    NaN      NaN                             Indian, Halal, Seafood
# 23821    4.4     40.0                                            Mexican
# 23836    4.7     75.0                       Chinese, Asian, Asian Fusion
# 23867    NaN      NaN                                           American
# ...      ...      ...                                                ...
# 27650    4.8     10.0                       American, Burgers, Fast Food
# 27655    3.4     56.0                                   Healthy, Mexican
# 27670    4.9     17.0                      Fast Food, Sandwich, American
# 28466    4.0     40.0                       American, Burgers, Fast Food
# 28469    4.7     14.0  American, Chicken, Family Meals, Fried Chicken...
#
#       price_range                                       full_address zip_code  \
# 23786         NaN    10820 Ashton Poole Place, Glen Allen, VA, 23059    23059
# 23791          $$                7801 W Broad St, Henrico, VA, 23294    23294
# 23821          $$       10282 Staples Mill Rd, Glen Allen, VA, 23060    23060
# 23836           $  1090 Virginia Center Pkwy Ste 102, Glen Allen,...    23059
# 23867           $               9990 Brook Rd, Glen Allen, VA, 23059    23059
# ...           ...                                                ...      ...
# 27650           $            10177 Brook Road, Glen Allen, VA, 23059    23059
# 27655           $  1070 Virginia Center Pkwy Ste 101, Glen Allen,...    23059
# 27670           $               7250 W Broad St, Richmond, VA, 23294    23294
# 28466           $               10000 BROOK RD, Fairfield, VA, 23059    23059
# 28469           $    10213 Washington Highway, Glen Allen, VA, 23059    23059
#
#              lat        lng
# 23786  37.679058 -77.470770
# 23791  37.620291 -77.525813
# 23821  37.657375 -77.526215
# 23836  37.668303 -77.458850
# 23867  37.670890 -77.461190
# ...          ...        ...
# 27650  37.675872 -77.460446
# 27655  37.667178 -77.459192
# 27670  37.614830 -77.521420
# 28466  37.671886 -77.461500
# 28469  37.684129 -77.462294
#
# [190 rows x 11 columns]

# %%
rsltdf = df.query('zip_code=="23060" or zip_code=="23059" or zip_code=="23058"' ) #testing with queries
rsltdf
# Out:
#           id  position                                               name  \
# 23786  23787       126                                       Crab Du Jour
# 23821  23822        56  Nuevo Mexico Restaurante (Richmond - Staples M...
# 23836  23837        12                              True Taste Restaurant
# 23867  23868       220                 Songwriters Cafe (9990 Brook Road)
# 23902  23903       181                                              Pitsa
# ...      ...       ...                                                ...
# 27655  27656        44  Chipotle Mexican Grill (1070 Virginia Center P...
# 27658  27659         3                          Walgreens (9801 BROOK RD)
# 28466  28467        12                       McDonald's® (10000 BROOK RD)
# 28469  28470         5                 Popeyes (10213 Washington Highway)
# 28473  28474         1                         Wawa 677 (8800 Brook Road)
#
#        score  ratings                                           category  \
# 23786    NaN      NaN                            Seafood, Chicken, Wings
# 23821    4.4     40.0                                            Mexican
# 23836    4.7     75.0                       Chinese, Asian, Asian Fusion
# 23867    NaN      NaN                                           American
# 23902    4.6     13.0                      Pizza, American, Comfort Food
# ...      ...      ...                                                ...
# 27655    3.4     56.0                                   Healthy, Mexican
# 27658    NaN      NaN   Pharmacy, Convenience, Everyday Essentials, Baby
# 28466    4.0     40.0                       American, Burgers, Fast Food
# 28469    4.7     14.0  American, Chicken, Family Meals, Fried Chicken...
# 28473    4.5     19.0  Salads, Juice and Smoothies, Sandwich, Deli, C...
#
#       price_range                                       full_address zip_code  \
# 23786         NaN    10820 Ashton Poole Place, Glen Allen, VA, 23059    23059
# 23821          $$       10282 Staples Mill Rd, Glen Allen, VA, 23060    23060
# 23836           $  1090 Virginia Center Pkwy Ste 102, Glen Allen,...    23059
# 23867           $               9990 Brook Rd, Glen Allen, VA, 23059    23059
# 23902         NaN  1080 Virginia Center Parkway, STE 101, Glen Al...    23059
# ...           ...                                                ...      ...
# 27655           $  1070 Virginia Center Pkwy Ste 101, Glen Allen,...    23059
# 27658           $               9801 Brook Rd, Glen Allen, VA, 23059    23059
# 28466           $               10000 BROOK RD, Fairfield, VA, 23059    23059
# 28469           $    10213 Washington Highway, Glen Allen, VA, 23059    23059
# 28473           $             8800 Brook Road, Glen Allen, VA, 23060    23060
#
#              lat        lng
# 23786  37.679058 -77.470770
# 23821  37.657375 -77.526215
# 23836  37.668303 -77.458850
# 23867  37.670890 -77.461190
# 23902  37.667590 -77.459110
# ...          ...        ...
# 27655  37.667178 -77.459192
# 27658  37.666620 -77.459900
# 28466  37.671886 -77.461500
# 28469  37.684129 -77.462294
# 28473  37.642914 -77.461000
#
# [84 rows x 11 columns]

# %% [markdown]
# #first, rating and number of reviews. then, cost. then, cuisine. Next, Take the highest rated resturants and time it with the number of ratings and highest value is best. zip code although is highest ranked and then ratings alone then both rating and number of reviews.

# %%
score_df= df['score']
score_df.dropna(inplace=True)
#userInput = input("Enter a : ")
#total_score_df= (score_df.loc[:, "score"] + ratings_df.loc["ratings")
score_df
# Out:
# 4        4.7
# 6        4.7
# 13       4.6
# 15       5.0
# 18       4.9
#         ...
# 63448    4.8
# 63460    4.4
# 63462    5.0
# 63464    4.6
# 63467    4.3
# Name: score, Length: 35302, dtype: float64

# %%
df_length = len(df)
n_scores = len(df['score'].unique())
n_ratings = len(df['ratings'].unique())
print(f"Length of data frame: {df_length}")
print(f"Scores: {n_scores}")
print(f"Ratings: {n_ratings}")
#n_users = len(ratings_df['userId'].unique())
# Out:
# Length of data frame: 63469
# Scores: 34
# Ratings: 434

# %%
mean_rating = filterDF['ratings'].mean() #mean of ratings column
#filterDF.groupby('zip_code')['ratings'].mean()
#.apply(lambda x: x.mean().index[0])
mean_rating
# Out:
# 68.5912408759124

# %%
'''
# loop through the rows using iterrows()
list_ratings = df['ratings'].tolist()
list_score = df['score'].tolist()

for index, row in filterDF.iterrows():
     n_ranking = (list_score[index]*mean_rating)+list_ratings[index]

#def test(x):
for index, row in filterDF.iterrows():
   n_ranking= (row['score']* mean_rating)+row['ratings']
   #df['rankings']=n_ranking
   print(n_ranking)
  # list = df[''].tolist() #can make smth a list
   df.assign(rankings= [n_ranking])
'''
filterDF['ranking'] = (filterDF['score']*mean_rating)+ filterDF['ratings'] #equation to get final value to determine the best resturant

print(df)

# df.apply(test, axis=1)
   # add the zip code next to the columns that correspond (hopefully instead of ID number)
# Out:
#           id  position                                            name  score  \
# 0          1        19               PJ Fresh (224 Daniel Payne Drive)    NaN
# 1          2         9                  J' ti`'z Smoothie-N-Coffee Bar    NaN
# 2          3         6  Philly Fresh Cheesesteaks (541-B Graymont Ave)    NaN
# 3          4        17         Papa Murphy's (1580 Montgomery Highway)    NaN
# 4          5       162                Nelson Brothers Cafe (17th St N)    4.7
# ...      ...       ...                                             ...    ...
# 63464  63465         2                           IHOP (4321 N 10th St)    4.6
# 63465  63466        29                       Feldman's - N 10th Street    NaN
# 63466  63467        27                           Feldman's - N 23rd St    NaN
# 63467  63468        19           Church's Chicken (620 S. 10th Street)    4.3
# 63468  63469         9                       7-Eleven (1600 S 23rd St)    NaN
#
#        ratings                                           category price_range  \
# 0          NaN                      Burgers, American, Sandwiches           $
# 1          NaN   Coffee and Tea, Breakfast and Brunch, Bubble Tea         NaN
# 2          NaN         American, Cheesesteak, Sandwiches, Alcohol           $
# 3          NaN                                              Pizza           $
# 4         22.0          Breakfast and Brunch, Burgers, Sandwiches         NaN
# ...        ...                                                ...         ...
# 63464     56.0  American, Breakfast and Brunch, burger, Comfor...           $
# 63465      NaN                                                NaN         NaN
# 63466      NaN                                                NaN         NaN
# 63467     17.0                            Fast Food, Family Meals           $
# 63468      NaN  Everyday Essentials, Convenience, Home &amp; P...           $
#
#                                             full_address zip_code        lat  \
# 0          224 Daniel Payne Drive, Birmingham, AL, 35207    35207  33.562365
# 1      1521 Pinson Valley Parkway, Birmingham, AL, 35217    35217  33.583640
# 2              541-B Graymont Ave, Birmingham, AL, 35204    35204  33.509800
# 3             1580 Montgomery Highway, Hoover, AL, 35226    35226  33.404439
# 4                   314 17th St N, Birmingham, AL, 35203    35203  33.514730
# ...                                                  ...      ...        ...
# 63464                4321 N 10th St, MC ALLEN, TX, 78504    78504  26.242853
# 63465                 3010 N 10th Street, Mc Allen, TX,       NaN  26.230764
# 63466              6101 N 23rd Street #B, Mc Allen, TX,       NaN  26.260353
# 63467             620 S. 10th Street, McAllen, TX, 78501    78501  26.197333
# 63468                 1600 S 23rd St, Mcallen, TX, 78503    78503  26.191710
#
#              lng
# 0     -86.830703
# 1     -86.773330
# 2     -86.854640
# 3     -86.806614
# 4     -86.811700
# ...          ...
# 63464 -98.223984
# 63465 -98.224922
# 63466 -98.236755
# 63467 -98.231369
# 63468 -98.247880
#
# [63469 rows x 11 columns]

# %%
filterDF.dropna(inplace=True) #get rid of NaN values
filterDF = filterDF.sort_values(by='ranking',ascending=False) #sort the dataset so that best rated places are top to bottom

# %%
filterDF
# Out:
#           id  position                                               name  \
# 27339  27340        12                     Chick-fil-A  (9100 W Broad St)
# 24510  24511       240        Outback Steakhouse (7917 West Broad Street)
# 27335  27336         1              Five Guys VA-0015 10841 West Broad St
# 25113  25114        47     TGI Friday's (1889 - Richmond, VA W Broad St))
# 25148  25149        83  Cracker Barrel Old Country Store (3620 Mayland...
# ...      ...       ...                                                ...
# 25054  25055        89                                        Kabab House
# 27655  27656        44  Chipotle Mexican Grill (1070 Virginia Center P...
# 23961  23962        85                  It's Just Wings (9950 Brook Road)
# 24754  24755        51                                      Genghis Grill
# 24688  24689       128                   Dave &amp; Buster's (Glen Allen)
#
#        score  ratings                                           category  \
# 27339    4.7    200.0  American, Fried Chicken, Family Meals, Souther...
# 24510    4.6    200.0  Burgers, American, Sandwiches, Steak, Seafood,...
# 27335    4.8    180.0                                  American, Burgers
# 25113    4.5    200.0          American, Burgers, Bar Food, Family Meals
# 25148    4.5    191.0        Burgers, American, Sandwiches, Family Meals
# ...      ...      ...                                                ...
# 25054    3.9     32.0                 Indian, Vegetarian, Asian, Healthy
# 27655    3.4     56.0                                   Healthy, Mexican
# 23961    3.8     25.0                                    American, Wings
# 24754    3.7     19.0     Asian, Mongolian, Vegetarian Friendly, Chinese
# 24688    3.4     10.0                           American, Burgers, Wings
#
#       price_range                                       full_address zip_code  \
# 27339           $               9100 W Broad St, Richmond, VA, 23294    23294
# 24510           $        7917 West Broad Street, Richmond, VA, 23294    23294
# 27335           $        10841 West Broad St., Glen Allen, VA, 23233    23233
# 25113          $$               7023 W Broad St, Richmond, VA, 23294    23294
# 25148           $            3620 Mayland Court, Richmond, VA, 23233    23233
# ...           ...                                                ...      ...
# 25054           $            3411 Old Parham Rd, Richmond, VA, 23294    23294
# 27655           $  1070 Virginia Center Pkwy Ste 101, Glen Allen,...    23059
# 23961          $$             9950 Brook Road, Glen Allen, VA, 23059    23059
# 24754          $$              11849 W. Broad St, Henrico, VA, 23233    23233
# 24688          $$        4001 Brownstone Blvd, Glen Allen, VA, 23233    23233
#
#              lat        lng        test
# 27339  37.637013 -77.550139  522.378832
# 24510  37.623010 -77.529055  515.519708
# 27335  37.645315 -77.583135  509.237956
# 25113  37.609508 -77.519643  508.660584
# 25148  37.639320 -77.570496  499.660584
# ...          ...        ...         ...
# 25054  37.628666 -77.535965  299.505839
# 27655  37.667178 -77.459192  289.210219
# 23961  37.669110 -77.461540  285.646715
# 24754  37.653882 -77.623255  272.787591
# 24688  37.648745 -77.604340  243.210219
#
# [124 rows x 12 columns]
